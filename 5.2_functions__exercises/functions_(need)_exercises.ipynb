# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Functions (Need) Exercises</span></div>

# %%
def greeting(name):
    if name == 'Batman':
        return 'Hello Batman! So, nice to meet you!'
    return f'Hello {name}!'

name = (input("Enter your name:"))

namee = greeting(name)
print(f" {namee}")
# Out:
# Enter your name: Batman
#  Hello Batman! So, nice to meet you!

# %% [markdown]
# if the name is not Batman, it will skip the if block entirely

# %%
def calculate_bmi(weight, height):
    bmi = weight / (height ** 2)

    if bmi < 18.5:
        return "Underweight"
    elif 18.5 <= bmi < 25:
        return "Normal weight"
    elif 25 <= bmi <= 29.9:
        return "Overweight"
    else:
        return "Obese"

weight = float(input("Enter your weight in kilograms: "))
height = float(input("Enter your height in meters: "))

bmi_category = calculate_bmi(weight, height)

print(f"Your BMI category: {bmi_category}")
# Out:
# Enter your weight in kilograms:  99.8
# Enter your height in meters:  2
# Your BMI category: Normal weight

# %%
def factorial(n):
    if n < 0:
        return "Factorial is not defined for negative numbers"
    if n == 0:
        return 1

    initial_result = 1
    
    for i in range(1, n + 1):
        initial_result *= i
    
    return initial_result

try:
    n = int(input("Find the factorial of: "))
    fac = factorial(n)
    print(f"The factorial of {n} is: {fac}")
except ValueError:
    print("Please enter a valid integer.")
# Out:
# Find the factorial of:  9
# The factorial of 9 is: 362880
